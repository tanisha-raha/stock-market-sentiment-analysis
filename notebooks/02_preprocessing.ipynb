# %% [markdown]
# # Preprocessing
# Inspect the reusable cleaning and label normalisation functions.

# %%
from src.preprocessing import clean_text, normalize_label
clean_text('RT @analyst: #Bullish earnings! https://example.com'), normalize_label(-1)
