# %% [markdown]
# # Baseline models
# This calls the leakage-safe split and training pipeline.

# %%
from src.data_loader import load_dataset
from src.train import train_baselines
df, warnings = load_dataset('../data/raw/dataset.csv')
comparison, test_data = train_baselines(df, models_dir='../models', metrics_dir='../outputs/metrics', figures_dir='../outputs/figures')
comparison
