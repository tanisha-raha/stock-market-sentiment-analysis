# %% [markdown]
# # EDA
# Load your local CSV and inspect dimensions, types, missingness, duplicates, class balance, text length, ticker counts, and post dates. No results are embedded.

# %%
from src.data_loader import load_dataset
df, warnings = load_dataset('../data/raw/dataset.csv')
print(df.shape, warnings)
df.info(); display(df.sentiment.value_counts())
df.assign(text_length=df.text.str.len()).text_length.describe()
